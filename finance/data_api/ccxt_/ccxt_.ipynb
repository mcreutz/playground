# %%
import ccxt
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
bina = ccxt.binance()
bina.load_markets()
# Out:
# {'ETH/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 4, 'price': 6},
#   'limits': {'amount': {'min': 0.0001, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 922327.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 894.47088095}},
#   'id': 'ETHBTC',
#   'lowercaseId': 'ethbtc',
#   'symbol': 'ETH/BTC',
#   'base': 'ETH',
#   'quote': 'BTC',
#   'baseId': 'ETH',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '922327.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '894.47088095',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'LTC/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 6},
#   'limits': {'amount': {'min': 0.001, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 7256.76563307}},
#   'id': 'LTCBTC',
#   'lowercaseId': 'ltcbtc',
#   'symbol': 'LTC/BTC',
#   'base': 'LTC',
#   'quote': 'BTC',
#   'baseId': 'LTC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'LTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LTC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7256.76563307',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'BNB/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 6},
#   'limits': {'amount': {'min': 0.001, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 8498.45718485}},
#   'id': 'BNBBTC',
#   'lowercaseId': 'bnbbtc',
#   'symbol': 'BNB/BTC',
#   'base': 'BNB',
#   'quote': 'BTC',
#   'baseId': 'BNB',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'BNBBTC',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '8498.45718485',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'NEO/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 8687.54177206}},
#   'id': 'NEOBTC',
#   'lowercaseId': 'neobtc',
#   'symbol': 'NEO/BTC',
#   'base': 'NEO',
#   'quote': 'BTC',
#   'baseId': 'NEO',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'NEOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'NEO',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '8687.54177206',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'QTUM/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 1, 'price': 6},
#   'limits': {'amount': {'min': 0.1, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 4997.06872828}},
#   'id': 'QTUMETH',
#   'lowercaseId': 'qtumeth',
#   'symbol': 'QTUM/ETH',
#   'base': 'QTUM',
#   'quote': 'ETH',
#   'baseId': 'QTUM',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'QTUMETH',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '4997.06872828',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'EOS/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 1, 'price': 6},
#   'limits': {'amount': {'min': 0.1, 'max': 92141578.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 26096.35755385}},
#   'id': 'EOSETH',
#   'lowercaseId': 'eoseth',
#   'symbol': 'EOS/ETH',
#   'base': 'EOS',
#   'quote': 'ETH',
#   'baseId': 'EOS',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'EOSETH',
#    'status': 'TRADING',
#    'baseAsset': 'EOS',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '26096.35755385',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'SNT/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 563843.69631688}},
#   'id': 'SNTETH',
#   'lowercaseId': 'snteth',
#   'symbol': 'SNT/ETH',
#   'base': 'SNT',
#   'quote': 'ETH',
#   'baseId': 'SNT',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'SNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'SNT',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '563843.69631688',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'BNT/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 1, 'price': 6},
#   'limits': {'amount': {'min': 0.1, 'max': 92141578.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 8745.40069492}},
#   'id': 'BNTETH',
#   'lowercaseId': 'bnteth',
#   'symbol': 'BNT/ETH',
#   'base': 'BNT',
#   'quote': 'ETH',
#   'baseId': 'BNT',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'BNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNT',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '8745.40069492',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'BCC/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 6},
#   'limits': {'amount': {'min': 0.001, 'max': 92141578.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'BCCBTC',
#   'lowercaseId': 'bccbtc',
#   'symbol': 'BCC/BTC',
#   'base': 'BCC',
#   'quote': 'BTC',
#   'baseId': 'BCC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'BCCBTC',
#    'status': 'BREAK',
#    'baseAsset': 'BCC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'GAS/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 1, 'price': 7},
#   'limits': {'amount': {'min': 0.1, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 10056.02209867}},
#   'id': 'GASBTC',
#   'lowercaseId': 'gasbtc',
#   'symbol': 'GAS/BTC',
#   'base': 'GAS',
#   'quote': 'BTC',
#   'baseId': 'GAS',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'GASBTC',
#    'status': 'TRADING',
#    'baseAsset': 'GAS',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '10056.02209867',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'BNB/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 4},
#   'limits': {'amount': {'min': 0.001, 'max': 9000000.0},
#    'price': {'min': 0.0001, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 3041.5250813}},
#   'id': 'BNBETH',
#   'lowercaseId': 'bnbeth',
#   'symbol': 'BNB/ETH',
#   'base': 'BNB',
#   'quote': 'ETH',
#   'baseId': 'BNB',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'BNBETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '3041.52508130',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'BTC/USDT': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 5, 'price': 2},
#   'limits': {'amount': {'min': 1e-05, 'max': 9000.0},
#    'price': {'min': 0.01, 'max': 1000000.0},
#    'cost': {'min': 10.0, 'max': None},
#    'market': {'min': 0.0, 'max': 110.46308623}},
#   'id': 'BTCUSDT',
#   'lowercaseId': 'btcusdt',
#   'symbol': 'BTC/USDT',
#   'base': 'BTC',
#   'quote': 'USDT',
#   'baseId': 'BTC',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'BTCUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'BTC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'USDT',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '110.46308623',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'ETH/USDT': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 4, 'price': 2},
#   'limits': {'amount': {'min': 0.0001, 'max': 9000.0},
#    'price': {'min': 0.01, 'max': 1000000.0},
#    'cost': {'min': 10.0, 'max': None},
#    'market': {'min': 0.0, 'max': 1324.10721751}},
#   'id': 'ETHUSDT',
#   'lowercaseId': 'ethusdt',
#   'symbol': 'ETH/USDT',
#   'base': 'ETH',
#   'quote': 'USDT',
#   'baseId': 'ETH',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'ETHUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'USDT',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1324.10721751',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'HSR/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 92141578.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'HSRBTC',
#   'lowercaseId': 'hsrbtc',
#   'symbol': 'HSR/BTC',
#   'base': 'HSR',
#   'quote': 'BTC',
#   'baseId': 'HSR',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'HSRBTC',
#    'status': 'BREAK',
#    'baseAsset': 'HSR',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'OAX/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 579591.88919668}},
#   'id': 'OAXETH',
#   'lowercaseId': 'oaxeth',
#   'symbol': 'OAX/ETH',
#   'base': 'OAX',
#   'quote': 'ETH',
#   'baseId': 'OAX',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'OAXETH',
#    'status': 'BREAK',
#    'baseAsset': 'OAX',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '579591.88919668',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'DNT/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 4194220.05124836}},
#   'id': 'DNTETH',
#   'lowercaseId': 'dnteth',
#   'symbol': 'DNT/ETH',
#   'base': 'DNT',
#   'quote': 'ETH',
#   'baseId': 'DNT',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'DNTETH',
#    'status': 'BREAK',
#    'baseAsset': 'DNT',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '4194220.05124836',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'MCO/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 6660.9552982}},
#   'id': 'MCOETH',
#   'lowercaseId': 'mcoeth',
#   'symbol': 'MCO/ETH',
#   'base': 'MCO',
#   'quote': 'ETH',
#   'baseId': 'MCO',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'MCOETH',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '6660.95529820',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'ICN/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None}},
#   'id': 'ICNETH',
#   'lowercaseId': 'icneth',
#   'symbol': 'ICN/ETH',
#   'base': 'ICN',
#   'quote': 'ETH',
#   'baseId': 'ICN',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'ICNETH',
#    'status': 'BREAK',
#    'baseAsset': 'ICN',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'MCO/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 7},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 27097.31944518}},
#   'id': 'MCOBTC',
#   'lowercaseId': 'mcobtc',
#   'symbol': 'MCO/BTC',
#   'base': 'MCO',
#   'quote': 'BTC',
#   'baseId': 'MCO',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'MCOBTC',
#    'status': 'BREAK',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '27097.31944518',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'WTC/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 9000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 62984.03335649}},
#   'id': 'WTCBTC',
#   'lowercaseId': 'wtcbtc',
#   'symbol': 'WTC/BTC',
#   'base': 'WTC',
#   'quote': 'BTC',
#   'baseId': 'WTC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'WTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '62984.03335649',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'WTC/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 28248.67398611}},
#   'id': 'WTCETH',
#   'lowercaseId': 'wtceth',
#   'symbol': 'WTC/ETH',
#   'base': 'WTC',
#   'quote': 'ETH',
#   'baseId': 'WTC',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'WTCETH',
#    'status': 'BREAK',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00500000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '28248.67398611',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': False,
#   'contractSize': None},
#  'LRC/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 204595.63377345}},
#   'id': 'LRCBTC',
#   'lowercaseId': 'lrcbtc',
#   'symbol': 'LRC/BTC',
#   'base': 'LRC',
#   'quote': 'BTC',
#   'baseId': 'LRC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'LRCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '204595.63377345',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'LRC/ETH': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.005, 'max': None},
#    'market': {'min': 0.0, 'max': 74883.82835302}},
#   'id': 'LRCETH',
#   'lowercaseId': 'lrceth',
#   'symbol': 'LRC/ETH',
#   'base': 'LRC',
#   'quote': 'ETH',
#   'baseId': 'LRC',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'LRCETH',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'ETH',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
# ...
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '34709.10854760',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'SUSHI/USDT': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 1, 'price': 3},
#   'limits': {'amount': {'min': 0.1, 'max': 90000.0},
#    'price': {'min': 0.001, 'max': 10000.0},
#    'cost': {'min': 10.0, 'max': None},
#    'market': {'min': 0.0, 'max': 149379.05350938}},
#   'id': 'SUSHIUSDT',
#   'lowercaseId': 'sushiusdt',
#   'symbol': 'SUSHI/USDT',
#   'base': 'SUSHI',
#   'quote': 'USDT',
#   'baseId': 'SUSHI',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'SUSHIUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'SUSHI',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'USDT',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00100000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00100000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '149379.05350938',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'YFII/BNB': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 4, 'price': 2},
#   'limits': {'amount': {'min': 0.0001, 'max': 90000.0},
#    'price': {'min': 0.01, 'max': 1000.0},
#    'cost': {'min': 0.05, 'max': None},
#    'market': {'min': 0.0, 'max': 5.27961466}},
#   'id': 'YFIIBNB',
#   'lowercaseId': 'yfiibnb',
#   'symbol': 'YFII/BNB',
#   'base': 'YFII',
#   'quote': 'BNB',
#   'baseId': 'YFII',
#   'quoteId': 'BNB',
#   'info': {'symbol': 'YFIIBNB',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BNB',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '90000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '5.27961466',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'YFII/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 4, 'price': 4},
#   'limits': {'amount': {'min': 0.0001, 'max': 92141578.0},
#    'price': {'min': 0.0001, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 29.80243287}},
#   'id': 'YFIIBTC',
#   'lowercaseId': 'yfiibtc',
#   'symbol': 'YFII/BTC',
#   'base': 'YFII',
#   'quote': 'BTC',
#   'baseId': 'YFII',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'YFIIBTC',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '92141578.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '29.80243287',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'YFII/BUSD': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 4, 'price': 0},
#   'limits': {'amount': {'min': 0.0001, 'max': 9000.0},
#    'price': {'min': 1.0, 'max': 1000000.0},
#    'cost': {'min': 10.0, 'max': None},
#    'market': {'min': 0.0, 'max': 19.23682925}},
#   'id': 'YFIIBUSD',
#   'lowercaseId': 'yfiibusd',
#   'symbol': 'YFII/BUSD',
#   'base': 'YFII',
#   'quote': 'BUSD',
#   'baseId': 'YFII',
#   'quoteId': 'BUSD',
#   'info': {'symbol': 'YFIIBUSD',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BUSD',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '1.00000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '1.00000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '19.23682925',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'YFII/USDT': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 4, 'price': 0},
#   'limits': {'amount': {'min': 0.0001, 'max': 9000.0},
#    'price': {'min': 1.0, 'max': 1000000.0},
#    'cost': {'min': 10.0, 'max': None},
#    'market': {'min': 0.0, 'max': 69.70087114}},
#   'id': 'YFIIUSDT',
#   'lowercaseId': 'yfiiusdt',
#   'symbol': 'YFII/USDT',
#   'base': 'YFII',
#   'quote': 'USDT',
#   'baseId': 'YFII',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'YFIIUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'YFII',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'USDT',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '1.00000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '1.00000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00010000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00010000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '69.70087114',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'KSM/BNB': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 4},
#   'limits': {'amount': {'min': 0.001, 'max': 900000.0},
#    'price': {'min': 0.0001, 'max': 10000.0},
#    'cost': {'min': 0.05, 'max': None},
#    'market': {'min': 0.0, 'max': 137.77622793}},
#   'id': 'KSMBNB',
#   'lowercaseId': 'ksmbnb',
#   'symbol': 'KSM/BNB',
#   'base': 'KSM',
#   'quote': 'BNB',
#   'baseId': 'KSM',
#   'quoteId': 'BNB',
#   'info': {'symbol': 'KSMBNB',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BNB',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '10000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.05000000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '137.77622793',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT']},
#   'spot': True,
#   'type': 'spot',
#   'margin': False,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  'KSM/BTC': {'percentage': True,
#   'feeSide': 'get',
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 6},
#   'limits': {'amount': {'min': 0.001, 'max': 10000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None},
#    'market': {'min': 0.0, 'max': 578.83658095}},
#   'id': 'KSMBTC',
#   'lowercaseId': 'ksmbtc',
#   'symbol': 'KSM/BTC',
#   'base': 'KSM',
#   'quote': 'BTC',
#   'baseId': 'KSM',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'KSMBTC',
#    'status': 'TRADING',
#    'baseAsset': 'KSM',
#    'baseAssetPrecision': '8',
#    'quoteAsset': 'BTC',
#    'quotePrecision': '8',
#    'quoteAssetPrecision': '8',
#    'baseCommissionPrecision': '8',
#    'quoteCommissionPrecision': '8',
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'quoteOrderQtyMarketAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': '5'},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '10000000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': '5'},
#     {'filterType': 'ICEBERG_PARTS', 'limit': '10'},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '578.83658095',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ORDERS', 'maxNumOrders': '200'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': '5'}],
#    'permissions': ['SPOT', 'MARGIN']},
#   'spot': True,
#   'type': 'spot',
#   'margin': True,
#   'future': False,
#   'delivery': False,
#   'linear': False,
#   'inverse': False,
#   'expiry': None,
#   'expiryDatetime': None,
#   'settleId': None,
#   'settle': None,
#   'active': True,
#   'contractSize': None},
#  ...}

# %%
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
#   'start':'1',
  'limit':'500',
#   'convert':'USD'
}
with open("../../secrets.json", 'r') as fr:
    content = "".join(fr.readlines())
    TOKEN = json.loads(content)['cmc_api_token']

headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': TOKEN,
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  # print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
data['data']
# Out:
# [{'id': 1,
#   'name': 'Bitcoin',
#   'symbol': 'BTC',
#   'slug': 'bitcoin',
#   'num_market_pairs': 8306,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'store-of-value',
#    'state-channel',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'galaxy-digital-portfolio',
#    'huobi-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital-portfolio',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-portfolio'],
#   'max_supply': 21000000,
#   'circulating_supply': 18888275,
#   'total_supply': 18888275,
#   'platform': None,
#   'cmc_rank': 1,
#   'last_updated': '2021-12-01T20:27:10.000Z',
#   'quote': {'USD': {'price': 56818.51533115176,
#     'volume_24h': 35405331248.557335,
#     'volume_change_24h': -7.6169,
#     'percent_change_1h': -1.00124914,
#     'percent_change_24h': -0.9160842,
#     'percent_change_7d': -0.64816765,
#     'percent_change_30d': -6.86741805,
#     'percent_change_60d': 18.58963819,
#     'percent_change_90d': 14.87145842,
#     'market_cap': 1073203742666.5105,
#     'market_cap_dominance': 40.8874,
#     'fully_diluted_market_cap': 1193188821954.19,
#     'last_updated': '2021-12-01T20:27:10.000Z'}}},
#  {'id': 1027,
#   'name': 'Ethereum',
#   'symbol': 'ETH',
#   'slug': 'ethereum',
#   'num_market_pairs': 4668,
#   'date_added': '2015-08-07T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'smart-contracts',
#    'ethereum-ecosystem',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'binance-labs-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'dcg-portfolio',
#    'dragonfly-capital-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'hashkey-capital-portfolio',
#    'kinetic-capital-portfolio',
#    'huobi-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    '1confirmation-portfolio',
#    'winklevoss-capital-portfolio',
#    'usv-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'multicoin-capital-portfolio',
#    'paradigm-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 118567151.124,
#   'total_supply': 118567151.124,
#   'platform': None,
#   'cmc_rank': 2,
#   'last_updated': '2021-12-01T20:27:06.000Z',
#   'quote': {'USD': {'price': 4582.414349149249,
#     'volume_24h': 26500266511.39241,
#     'volume_change_24h': -8.3579,
#     'percent_change_1h': -1.29517092,
#     'percent_change_24h': -1.20472911,
#     'percent_change_7d': 7.98947528,
#     'percent_change_30d': 5.62785271,
#     'percent_change_60d': 33.86175458,
#     'percent_change_90d': 21.03229491,
#     'market_cap': 543323814648.36505,
#     'market_cap_dominance': 20.6302,
#     'fully_diluted_market_cap': 543323814648.37,
#     'last_updated': '2021-12-01T20:27:06.000Z'}}},
#  {'id': 1839,
#   'name': 'Binance Coin',
#   'symbol': 'BNB',
#   'slug': 'binance-coin',
#   'num_market_pairs': 559,
#   'date_added': '2017-07-25T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'payments',
#    'smart-contracts',
#    'binance-smart-chain',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio'],
#   'max_supply': 166801148,
#   'circulating_supply': 166801148,
#   'total_supply': 166801148,
#   'platform': None,
#   'cmc_rank': 3,
#   'last_updated': '2021-12-01T20:28:03.000Z',
#   'quote': {'USD': {'price': 626.6289478738415,
#     'volume_24h': 2748878017.072139,
#     'volume_change_24h': 1.348,
#     'percent_change_1h': -1.27628468,
#     'percent_change_24h': 0.94008082,
#     'percent_change_7d': 7.0462341,
#     'percent_change_30d': 15.17949064,
#     'percent_change_60d': 44.16585148,
#     'percent_change_90d': 28.82030119,
#     'market_cap': 104522427875.38893,
#     'market_cap_dominance': 3.9688,
#     'fully_diluted_market_cap': 104522427875.39,
#     'last_updated': '2021-12-01T20:28:03.000Z'}}},
#  {'id': 825,
#   'name': 'Tether',
#   'symbol': 'USDT',
#   'slug': 'tether',
#   'num_market_pairs': 20110,
#   'date_added': '2015-02-25T00:00:00.000Z',
#   'tags': ['payments',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'binance-smart-chain',
#    'avalanche-ecosystem',
#    'solana-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 73578322706.64124,
#   'total_supply': 76351995265.76913,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdac17f958d2ee523a2206206994597c13d831ec7'},
#   'cmc_rank': 4,
#   'last_updated': '2021-12-01T20:28:03.000Z',
#   'quote': {'USD': {'price': 1.0002075778124482,
#     'volume_24h': 78489929573.90097,
#     'volume_change_24h': -11.4263,
#     'percent_change_1h': 0.02222605,
#     'percent_change_24h': 0.11348048,
#     'percent_change_7d': -0.04697319,
#     'percent_change_30d': -0.09193137,
#     'percent_change_60d': -0.00732757,
#     'percent_change_90d': 0.0276,
#     'market_cap': 73593595933.9123,
#     'market_cap_dominance': 2.8038,
#     'fully_diluted_market_cap': 76367844245.92,
#     'last_updated': '2021-12-01T20:28:03.000Z'}}},
#  {'id': 5426,
#   'name': 'Solana',
#   'symbol': 'SOL',
#   'slug': 'solana',
#   'num_market_pairs': 190,
#   'date_added': '2020-04-10T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'solana-ecosystem',
#    'cms-holdings-portfolio',
#    'kinetic-capital-portfolio',
#    'alameda-research-portfolio',
#    'multicoin-capital-portfolio',
#    'k300-ventures-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 305506907.1346582,
#   'total_supply': 510205803.6061045,
#   'platform': None,
#   'cmc_rank': 5,
#   'last_updated': '2021-12-01T20:27:10.000Z',
#   'quote': {'USD': {'price': 225.16805606668908,
#     'volume_24h': 3208370061.4532366,
#     'volume_change_24h': 12.2074,
#     'percent_change_1h': -0.10099953,
#     'percent_change_24h': 5.25377649,
#     'percent_change_7d': 9.91520572,
#     'percent_change_30d': 9.96462159,
#     'percent_change_60d': 31.01936913,
#     'percent_change_90d': 76.99659839,
#     'market_cap': 68790396394.45749,
#     'market_cap_dominance': 2.6108,
#     'fully_diluted_market_cap': 114882048991.93,
#     'last_updated': '2021-12-01T20:27:10.000Z'}}},
#  {'id': 2010,
#   'name': 'Cardano',
#   'symbol': 'ADA',
#   'slug': 'cardano',
#   'num_market_pairs': 298,
#   'date_added': '2017-10-01T00:00:00.000Z',
#   'tags': ['mineable',
#    'dpos',
#    'pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'staking',
#    'binance-smart-chain',
#    'cardano-ecosystem'],
#   'max_supply': 45000000000,
#   'circulating_supply': 33313246914.729,
#   'total_supply': 33719282563.077,
#   'platform': None,
#   'cmc_rank': 6,
#   'last_updated': '2021-12-01T20:27:53.000Z',
#   'quote': {'USD': {'price': 1.5578579053407868,
#     'volume_24h': 1602469800.3824656,
#     'volume_change_24h': -15.7785,
#     'percent_change_1h': -1.28547808,
#     'percent_change_24h': -0.49949657,
#     'percent_change_7d': -5.05313932,
#     'percent_change_30d': -19.8785352,
#     'percent_change_60d': -32.06816451,
#     'percent_change_90d': -47.48995759,
#     'market_cap': 51897305058.68015,
#     'market_cap_dominance': 1.9697,
#     'fully_diluted_market_cap': 70103605740.34,
#     'last_updated': '2021-12-01T20:27:53.000Z'}}},
#  {'id': 52,
#   'name': 'XRP',
#   'symbol': 'XRP',
#   'slug': 'xrp',
#   'num_market_pairs': 615,
#   'date_added': '2013-08-04T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'binance-chain',
#    'arrington-xrp-capital-portfolio',
#    'galaxy-digital-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio'],
#   'max_supply': 100000000000,
#   'circulating_supply': 47216103219,
#   'total_supply': 99990106991,
#   'platform': None,
#   'cmc_rank': 7,
#   'last_updated': '2021-12-01T20:27:06.000Z',
#   'quote': {'USD': {'price': 0.9915340238287385,
#     'volume_24h': 2531443090.752736,
#     'volume_change_24h': -18.043,
#     'percent_change_1h': -1.11225114,
#     'percent_change_24h': -1.0787058,
#     'percent_change_7d': -3.43466331,
#     'percent_change_30d': -9.15480978,
#     'percent_change_60d': -5.88756687,
#     'percent_change_90d': -21.18903621,
#     'market_cap': 46816372814.24812,
#     'market_cap_dominance': 1.7768,
#     'fully_diluted_market_cap': 99153402382.87,
#     'last_updated': '2021-12-01T20:27:06.000Z'}}},
#  {'id': 3408,
#   'name': 'USD Coin',
#   'symbol': 'USDC',
#   'slug': 'usd-coin',
#   'num_market_pairs': 1685,
#   'date_added': '2018-10-08T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'binance-smart-chain',
#    'fantom-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 38898200868.476326,
#   'total_supply': 38898200868.476326,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   'cmc_rank': 8,
#   'last_updated': '2021-12-01T20:27:40.000Z',
#   'quote': {'USD': {'price': 0.999506464712004,
#     'volume_24h': 4707329907.409171,
#     'volume_change_24h': -17.341,
#     'percent_change_1h': -0.13835055,
#     'percent_change_24h': 0.01600799,
#     'percent_change_7d': -0.10805963,
#     'percent_change_30d': -0.09816073,
#     'percent_change_60d': -0.01857517,
#     'percent_change_90d': -0.01136969,
#     'market_cap': 38879003233.708176,
#     'market_cap_dominance': 1.4763,
#     'fully_diluted_market_cap': 38879003233.71,
#     'last_updated': '2021-12-01T20:27:40.000Z'}}},
#  {'id': 6636,
#   'name': 'Polkadot',
#   'symbol': 'DOT',
#   'slug': 'polkadot-new',
#   'num_market_pairs': 248,
#   'date_added': '2020-08-19T00:00:00.000Z',
#   'tags': ['substrate',
#    'polkadot',
#    'binance-chain',
#    'binance-smart-chain',
#    'polkadot-ecosystem',
#    'three-arrows-capital-portfolio',
#    'polychain-capital-portfolio',
#    'arrington-xrp-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'cms-holdings-portfolio',
#    'coinfund-portfolio',
#    'fabric-ventures-portfolio',
#    'fenbushi-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'kinetic-capital-portfolio',
#    '1confirmation-portfolio',
#    'placeholder-ventures-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio',
#    'web3'],
#   'max_supply': None,
#   'circulating_supply': 987579314.957085,
#   'total_supply': 1103303471.382273,
#   'platform': None,
#   'cmc_rank': 9,
#   'last_updated': '2021-12-01T20:27:57.000Z',
#   'quote': {'USD': {'price': 36.84817034713119,
#     'volume_24h': 1197293061.6918058,
#     'volume_change_24h': -25.2359,
#     'percent_change_1h': -1.25136303,
#     'percent_change_24h': -3.78708154,
#     'percent_change_7d': -4.61122644,
#     'percent_change_30d': -25.91136276,
#     'percent_change_60d': 12.72042201,
#     'percent_change_90d': 13.84494487,
#     'market_cap': 36390490828.84179,
#     'market_cap_dominance': 1.3811,
#     'fully_diluted_market_cap': 40654714258.08,
#     'last_updated': '2021-12-01T20:27:57.000Z'}}},
#  {'id': 74,
#   'name': 'Dogecoin',
#   'symbol': 'DOGE',
#   'slug': 'dogecoin',
#   'num_market_pairs': 404,
#   'date_added': '2013-12-15T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'memes',
#    'payments',
#    'binance-smart-chain',
#    'doggone-doggerel'],
#   'max_supply': None,
#   'circulating_supply': 132345354982.32431,
#   'total_supply': 132345354982.32431,
#   'platform': None,
#   'cmc_rank': 10,
#   'last_updated': '2021-12-01T20:27:20.000Z',
#   'quote': {'USD': {'price': 0.2075242325022807,
#     'volume_24h': 939427026.8412184,
#     'volume_change_24h': -50.2898,
#     'percent_change_1h': -1.89252976,
#     'percent_change_24h': -3.81151309,
#     'percent_change_7d': -4.31721508,
#     'percent_change_30d': -23.40447859,
#     'percent_change_60d': -6.60712349,
#     'percent_change_90d': -30.59153857,
#     'market_cap': 27464868217.948742,
#     'market_cap_dominance': 1.0424,
#     'fully_diluted_market_cap': 27464868217.95,
#     'last_updated': '2021-12-01T20:27:20.000Z'}}},
#  {'id': 5805,
#   'name': 'Avalanche',
#   'symbol': 'AVAX',
#   'slug': 'avalanche',
#   'num_market_pairs': 124,
#   'date_added': '2020-07-13T00:00:00.000Z',
#   'tags': ['defi',
#    'smart-contracts',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'avalanche-ecosystem',
#    'cms-holdings-portfolio',
#    'dragonfly-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 223958103.15599048,
#   'total_supply': 394799944.8159905,
#   'platform': None,
#   'cmc_rank': 11,
#   'last_updated': '2021-12-01T20:27:54.000Z',
#   'quote': {'USD': {'price': 121.45456577856228,
#     'volume_24h': 1393002132.6147768,
#     'volume_change_24h': -20.8236,
#     'percent_change_1h': -2.33118939,
#     'percent_change_24h': -0.4208928,
#     'percent_change_7d': 3.09213988,
#     'percent_change_30d': 86.95019484,
#     'percent_change_60d': 71.53629457,
#     'percent_change_90d': 179.56412923,
#     'market_cap': 27200734171.401283,
#     'market_cap_dominance': 1.0323,
#     'fully_diluted_market_cap': 47950255867.03,
#     'last_updated': '2021-12-01T20:27:54.000Z'}}},
#  {'id': 5994,
#   'name': 'SHIBA INU',
#   'symbol': 'SHIB',
#   'slug': 'shiba-inu',
#   'num_market_pairs': 166,
#   'date_added': '2020-08-01T00:00:00.000Z',
#   'tags': ['memes', 'doggone-doggerel'],
#   'max_supply': None,
#   'circulating_supply': 549052602946547.2,
#   'total_supply': 589736613236608.5,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   'cmc_rank': 12,
#   'last_updated': '2021-12-01T20:28:04.000Z',
#   'quote': {'USD': {'price': 4.463522002317224e-05,
#     'volume_24h': 3805402532.255508,
#     'volume_change_24h': -60.857,
#     'percent_change_1h': -1.76646404,
#     'percent_change_24h': -6.63174174,
#     'percent_change_7d': 17.69816508,
#     'percent_change_30d': -37.32411122,
#     'percent_change_60d': 449.585479,
#     'percent_change_90d': 530.55476523,
#     'market_cap': 24507083736.81456,
#     'market_cap_dominance': 0.9305,
#     'fully_diluted_market_cap': 26323023487.54,
#     'last_updated': '2021-12-01T20:28:04.000Z'}}},
#  {'id': 4172,
#   'name': 'Terra',
#   'symbol': 'LUNA',
#   'slug': 'terra-luna',
#   'num_market_pairs': 107,
#   'date_added': '2019-07-26T00:00:00.000Z',
#   'tags': ['cosmos-ecosystem',
#    'store-of-value',
#    'defi',
#    'payments',
#    'coinbase-ventures-portfolio',
#    'binance-labs-portfolio',
#    'solana-ecosystem',
#    'arrington-xrp-capital-portfolio',
#    'hashkey-capital-portfolio',
#    'kinetic-capital-portfolio',
#    'huobi-capital-portfolio',
#    'pantera-capital-portfolio',
#    'terra-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 389994457.26242906,
#   'total_supply': 866403524.416348,
#   'platform': None,
#   'cmc_rank': 13,
#   'last_updated': '2021-12-01T20:27:12.000Z',
#   'quote': {'USD': {'price': 61.530320248881,
#     'volume_24h': 2115807803.77602,
#     'volume_change_24h': -9.3469,
#     'percent_change_1h': -2.97447389,
#     'percent_change_24h': 4.36192156,
#     'percent_change_7d': 57.9189748,
#     'percent_change_30d': 43.52061602,
#     'percent_change_60d': 46.82457069,
#     'percent_change_90d': 88.6061373,
#     'market_cap': 23996483850.645794,
#     'market_cap_dominance': 0.9107,
#     'fully_diluted_market_cap': 53310086322.1,
#     'last_updated': '2021-12-01T20:27:12.000Z'}}},
#  {'id': 3635,
#   'name': 'Crypto.com Coin',
#   'symbol': 'CRO',
#   'slug': 'crypto-com-coin',
#   'num_market_pairs': 113,
#   'date_added': '2018-12-14T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'cosmos-ecosystem',
#    'centralized-exchange',
#    'mobile',
#    'payments'],
#   'max_supply': 30263013692,
#   'circulating_supply': 25263013692,
#   'total_supply': 30263013692,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   'cmc_rank': 14,
#   'last_updated': '2021-12-01T20:27:56.000Z',
#   'quote': {'USD': {'price': 0.717844404892876,
#     'volume_24h': 614678655.9056164,
#     'volume_change_24h': 6.7022,
#     'percent_change_1h': -1.52790804,
#     'percent_change_24h': 4.30134462,
#     'percent_change_7d': -22.77347039,
#     'percent_change_30d': 237.05425982,
#     'percent_change_60d': 304.29411118,
#     'percent_change_90d': 341.30914749,
#     'market_cap': 18134913029.53432,
#     'market_cap_dominance': 0.6883,
#     'fully_diluted_market_cap': 21724135054,
#     'last_updated': '2021-12-01T20:27:56.000Z'}}},
#  {'id': 2,
#   'name': 'Litecoin',
#   'symbol': 'LTC',
#   'slug': 'litecoin',
#   'num_market_pairs': 673,
#   'date_added': '2013-04-28T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'scrypt',
#    'medium-of-exchange',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': 84000000,
#   'circulating_supply': 69093607.3175727,
#   'total_supply': 84000000,
#   'platform': None,
#   'cmc_rank': 15,
#   'last_updated': '2021-12-01T20:27:04.000Z',
#   'quote': {'USD': {'price': 208.1352962069981,
#     'volume_24h': 1683573284.2688878,
#     'volume_change_24h': -22.442,
#     'percent_change_1h': -1.11153487,
#     'percent_change_24h': -0.83532715,
#     'percent_change_7d': -0.73154801,
#     'percent_change_30d': 7.34635028,
#     'percent_change_60d': 22.01471478,
#     'percent_change_90d': 12.09146856,
#     'market_cap': 14380818425.053005,
#     'market_cap_dominance': 0.5458,
#     'fully_diluted_market_cap': 17483364881.39,
#     'last_updated': '2021-12-01T20:27:04.000Z'}}},
#  {'id': 3717,
#   'name': 'Wrapped Bitcoin',
#   'symbol': 'WBTC',
#   'slug': 'wrapped-bitcoin',
#   'num_market_pairs': 179,
#   'date_added': '2019-01-30T00:00:00.000Z',
#   'tags': ['medium-of-exchange', 'defi', 'wrapped-tokens', 'fantom-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 253975.89155071,
#   'total_supply': 253975.89155071,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   'cmc_rank': 16,
#   'last_updated': '2021-12-01T20:28:02.000Z',
#   'quote': {'USD': {'price': 56146.466661173894,
#     'volume_24h': 332134511.0041949,
#     'volume_change_24h': -1.3488,
#     'percent_change_1h': -0.52965259,
#     'percent_change_24h': -0.42396701,
#     'percent_change_7d': -0.50048484,
#     'percent_change_30d': -8.11710179,
#     'percent_change_60d': 17.01561506,
#     'percent_change_90d': 13.35165357,
#     'market_cap': 14259848927.693855,
#     'market_cap_dominance': 0.5412,
#     'fully_diluted_market_cap': 14259848927.69,
#     'last_updated': '2021-12-01T20:28:02.000Z'}}},
#  {'id': 3890,
#   'name': 'Polygon',
#   'symbol': 'MATIC',
#   'slug': 'polygon',
#   'num_market_pairs': 251,
#   'date_added': '2019-04-28T00:00:00.000Z',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'state-channel',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'polygon-ecosystem'],
#   'max_supply': 10000000000,
#   'circulating_supply': 7021682963.27,
#   'total_supply': 10000000000,
#   'platform': None,
#   'cmc_rank': 17,
#   'last_updated': '2021-12-01T20:28:03.000Z',
#   'quote': {'USD': {'price': 1.9543641064100705,
#     'volume_24h': 2334318552.6845875,
#     'volume_change_24h': 54.9706,
#     'percent_change_1h': -2.06580037,
#     'percent_change_24h': 7.57729281,
#     'percent_change_7d': 15.34162485,
#     'percent_change_30d': 3.59939745,
#     'percent_change_60d': 47.76430947,
#     'percent_change_90d': 33.95803068,
#     'market_cap': 13722925150.005991,
#     'market_cap_dominance': 0.5211,
#     'fully_diluted_market_cap': 19543641064.1,
#     'last_updated': '2021-12-01T20:28:03.000Z'}}},
#  {'id': 4687,
#   'name': 'Binance USD',
#   'symbol': 'BUSD',
#   'slug': 'binance-usd',
#   'num_market_pairs': 1472,
#   'date_added': '2019-09-20T00:00:00.000Z',
#   'tags': ['stablecoin',
#    'asset-backed-stablecoin',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 13578169256.12,
#   'total_supply': 13578169256.12,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'BUSD-BD1'},
#   'cmc_rank': 18,
#   'last_updated': '2021-12-01T20:27:44.000Z',
#   'quote': {'USD': {'price': 0.9984676358119217,
#     'volume_24h': 7899639682.162218,
#     'volume_change_24h': 0.5963,
#     'percent_change_1h': -0.24022305,
#     'percent_change_24h': -0.14655125,
#     'percent_change_7d': -0.15419156,
#     'percent_change_30d': -0.22669358,
#     'percent_change_60d': -0.13660232,
#     'percent_change_90d': -0.10132995,
#     'market_cap': 13557362555.812256,
#     'market_cap_dominance': 0.5145,
#     'fully_diluted_market_cap': 13557362555.81,
#     'last_updated': '2021-12-01T20:27:44.000Z'}}},
#  {'id': 7083,
#   'name': 'Uniswap',
#   'symbol': 'UNI',
#   'slug': 'uniswap',
#   'num_market_pairs': 279,
#   'date_added': '2020-09-17T00:00:00.000Z',
#   'tags': ['decentralized-exchange',
#    'defi',
#    'dao',
#    'yield-farming',
#    'amm',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'three-arrows-capital-portfolio',
#    'governance',
#    'blockchain-capital-portfolio',
#    'defiance-capital-portfolio',
#    'alameda-research-portfolio',
#    'a16z-portfolio',
#    'pantera-capital-portfolio',
#    'parafi-capital',
#    'paradigm-portfolio',
#    'arbitrum-ecosytem'],
#   'max_supply': 1000000000,
#   'circulating_supply': 627904919.3554093,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   'cmc_rank': 19,
#   'last_updated': '2021-12-01T20:28:05.000Z',
#   'quote': {'USD': {'price': 21.052518944192318,
#     'volume_24h': 355008361.47825104,
#     'volume_change_24h': 29.7392,
#     'percent_change_1h': -1.3194369,
#     'percent_change_24h': 0.77873617,
#     'percent_change_7d': 1.0709859,
#     'percent_change_30d': -18.50268349,
#     'percent_change_60d': -21.1092804,
#     'percent_change_90d': -29.74680525,
#     'market_cap': 13218980209.881304,
#     'market_cap_dominance': 0.5036,
#     'fully_diluted_market_cap': 21052518944.19,
#     'last_updated': '2021-12-01T20:28:05.000Z'}}},
#  {'id': 4030,
#   'name': 'Algorand',
#   'symbol': 'ALGO',
#   'slug': 'algorand',
#   'num_market_pairs': 158,
#   'date_added': '2019-06-20T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'research',
#    'smart-contracts',
#    'arrington-xrp-capital-portfolio',
#    'kinetic-capital-portfolio',
#    'usv-portfolio',
#    'multicoin-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 10000000000,
#   'circulating_supply': 6286854314.165904,
#   'total_supply': 6739359546.738294,
#   'platform': None,
#   'cmc_rank': 20,
#   'last_updated': '2021-12-01T20:28:00.000Z',
#   'quote': {'USD': {'price': 1.9193188864317388,
#     'volume_24h': 729061451.3405355,
#     'volume_change_24h': 41.6024,
#     'percent_change_1h': -2.61348256,
#     'percent_change_24h': 5.95701219,
#     'percent_change_7d': 9.75404211,
#     'percent_change_30d': 4.75256174,
#     'percent_change_60d': 5.21757178,
#     'percent_change_90d': 67.31900791,
#     'market_cap': 12066478221.423475,
#     'market_cap_dominance': 0.458,
#     'fully_diluted_market_cap': 19193188864.32,
#     'last_updated': '2021-12-01T20:28:00.000Z'}}},
#  {'id': 1975,
#   'name': 'Chainlink',
#   'symbol': 'LINK',
#   'slug': 'chainlink',
#   'num_market_pairs': 467,
#   'date_added': '2017-09-20T00:00:00.000Z',
#   'tags': ['platform',
#    'defi',
#    'oracles',
#    'smart-contracts',
#    'substrate',
#    'polkadot',
#    'binance-smart-chain',
#    'polkadot-ecosystem',
#    'avalanche-ecosystem',
#    'solana-ecosystem',
#    'framework-ventures-portfolio',
#    'polygon-ecosystem',
#    'fantom-ecosystem',
#    'web3',
#    'near-protocol-ecosystem'],
#   'max_supply': 1000000000,
#   'circulating_supply': 467009553.9174637,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x514910771af9ca656af840dff83e8264ecf986ca'},
#   'cmc_rank': 21,
#   'last_updated': '2021-12-01T20:28:05.000Z',
#   'quote': {'USD': {'price': 25.550059943208947,
#     'volume_24h': 879496294.757658,
#     'volume_change_24h': -15.0534,
#     'percent_change_1h': -1.65330445,
#     'percent_change_24h': -1.16630701,
#     'percent_change_7d': 0.17459219,
#     'percent_change_30d': -17.9238645,
#     'percent_change_60d': -6.59824414,
#     'percent_change_90d': -16.07969596,
#     'market_cap': 11932122096.64247,
#     'market_cap_dominance': 0.4529,
#     'fully_diluted_market_cap': 25550059943.21,
#     'last_updated': '2021-12-01T20:28:05.000Z'}}},
#  {'id': 1831,
#   'name': 'Bitcoin Cash',
#   'symbol': 'BCH',
#   'slug': 'bitcoin-cash',
#   'num_market_pairs': 524,
#   'date_added': '2017-07-23T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'sha-256',
#    'marketplace',
#    'medium-of-exchange',
#    'store-of-value',
#    'enterprise-solutions',
#    'payments',
#    'binance-chain',
#    'binance-smart-chain'],
#   'max_supply': 21000000,
#   'circulating_supply': 18915781.25,
#   'total_supply': 18915781.25,
#   'platform': None,
#   'cmc_rank': 22,
#   'last_updated': '2021-12-01T20:27:44.000Z',
#   'quote': {'USD': {'price': 571.1275232059606,
#     'volume_24h': 847894271.9115938,
#     'volume_change_24h': -30.348,
#     'percent_change_1h': -1.20667381,
#     'percent_change_24h': -0.0822899,
#     'percent_change_7d': -4.91132797,
#     'percent_change_30d': -2.78267965,
#     'percent_change_60d': 2.68499243,
#     'percent_change_90d': -14.02794709,
#     'market_cap': 10803323294.81825,
#     'market_cap_dominance': 0.41,
#     'fully_diluted_market_cap': 11993677987.33,
#     'last_updated': '2021-12-01T20:27:44.000Z'}}},
#  {'id': 1966,
#   'name': 'Decentraland',
#   'symbol': 'MANA',
#   'slug': 'decentraland',
#   'num_market_pairs': 191,
#   'date_added': '2017-09-17T00:00:00.000Z',
#   'tags': ['platform',
#    'collectibles-nfts',
#    'gaming',
#    'payments',
#    'metaverse',
#    'boostvc-portfolio',
#    'dcg-portfolio',
#    'fabric-ventures-portfolio',
#    'kinetic-capital-portfolio',
#    'polygon-ecosystem',
#    'play-to-earn'],
#   'max_supply': None,
#   'circulating_supply': 1824609434.8740842,
#   'total_supply': 2193974427.320146,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0f5d2fb29fb7d3cfee444a200298f468908cc942'},
#   'cmc_rank': 23,
#   'last_updated': '2021-12-01T20:28:06.000Z',
#   'quote': {'USD': {'price': 4.570558721016441,
#     'volume_24h': 1769270615.7707887,
#     'volume_change_24h': -23.0628,
#     'percent_change_1h': -3.18754785,
#     'percent_change_24h': -1.38246203,
#     'percent_change_7d': -9.16947354,
#     'percent_change_30d': 54.0984735,
#     'percent_change_60d': 493.8695668,
#     'percent_change_90d': 373.29367104,
#     'market_cap': 8339484565.012627,
#     'market_cap_dominance': 0.3165,
#     'fully_diluted_market_cap': 10027688952.48,
#     'last_updated': '2021-12-01T20:28:06.000Z'}}},
#  {'id': 6783,
#   'name': 'Axie Infinity',
#   'symbol': 'AXS',
#   'slug': 'axie-infinity',
#   'num_market_pairs': 143,
#   'date_added': '2020-08-31T00:00:00.000Z',
#   'tags': ['collectibles-nfts',
#    'gaming',
#    'binance-launchpad',
#    'metaverse',
#    'defiance-capital-portfolio',
#    'play-to-earn',
#    'animoca-brands-portfolio'],
#   'max_supply': 270000000,
#   'circulating_supply': 60907500,
#   'total_supply': 270000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xbb0e17ef65f82ab018d8edd776e8dd940327b28b'},
#   'cmc_rank': 24,
#   'last_updated': '2021-12-01T20:27:32.000Z',
#   'quote': {'USD': {'price': 136.17018914205528,
#     'volume_24h': 452622311.8245068,
#     'volume_change_24h': 4.3694,
#     'percent_change_1h': -1.4440944,
#     'percent_change_24h': 0.48667651,
#     'percent_change_7d': -3.08814439,
#     'percent_change_30d': 0.26643607,
#     'percent_change_60d': 21.62535622,
#     'percent_change_90d': 87.5525611,
#     'market_cap': 8293785795.169732,
#     'market_cap_dominance': 0.3148,
#     'fully_diluted_market_cap': 36765951068.35,
#     'last_updated': '2021-12-01T20:27:32.000Z'}}},
#  {'id': 512,
#   'name': 'Stellar',
#   'symbol': 'XLM',
#   'slug': 'stellar',
#   'num_market_pairs': 327,
#   'date_added': '2014-08-05T00:00:00.000Z',
#   'tags': ['medium-of-exchange',
#    'enterprise-solutions',
#    'decentralized-exchange',
#    'smart-contracts',
#    'hashkey-capital-portfolio'],
#   'max_supply': 50001806812,
#   'circulating_supply': 24353251585.4677,
#   'total_supply': 50001802514.57283,
#   'platform': None,
#   'cmc_rank': 25,
#   'last_updated': '2021-12-01T20:27:54.000Z',
#   'quote': {'USD': {'price': 0.32970930495787815,
#     'volume_24h': 551825792.3787599,
#     'volume_change_24h': -27.9664,
#     'percent_change_1h': -0.75141307,
#     'percent_change_24h': -3.00110425,
#     'percent_change_7d': 1.49766455,
#     'percent_change_30d': -9.43367037,
#     'percent_change_60d': 4.53062483,
#     'percent_change_90d': -8.42271375,
#     'market_cap': 8029493653.7088995,
#     'market_cap_dominance': 0.3047,
#     'fully_diluted_market_cap': 16486060970.62,
#     'last_updated': '2021-12-01T20:27:54.000Z'}}},
#  {'id': 6892,
#   'name': 'Elrond',
#   'symbol': 'EGLD',
#   'slug': 'elrond-egld',
#   'num_market_pairs': 61,
#   'date_added': '2020-09-04T00:00:00.000Z',
#   'tags': ['binance-smart-chain',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'electric-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 31415926,
#   'circulating_supply': 19813813.76541377,
#   'total_supply': 22814513,
#   'platform': None,
#   'cmc_rank': 26,
#   'last_updated': '2021-12-01T20:28:02.000Z',
#   'quote': {'USD': {'price': 401.0443354631359,
#     'volume_24h': 356757683.61152405,
#     'volume_change_24h': 42.3024,
#     'percent_change_1h': -1.4845484,
#     'percent_change_24h': 3.42643423,
#     'percent_change_7d': -11.10626827,
#     'percent_change_30d': 48.89757059,
#     'percent_change_60d': 60.38830386,
#     'percent_change_90d': 131.05044815,
#     'market_cap': 7946217774.540699,
#     'market_cap_dominance': 0.3016,
#     'fully_diluted_market_cap': 12599179165.63,
#     'last_updated': '2021-12-01T20:28:02.000Z'}}},
#  {'id': 3077,
#   'name': 'VeChain',
#   'symbol': 'VET',
#   'slug': 'vechain',
#   'num_market_pairs': 151,
#   'date_added': '2017-08-22T00:00:00.000Z',
#   'tags': ['logistics',
#    'data-provenance',
#    'iot',
#    'smart-contracts',
#    'fenbushi-capital-portfolio'],
#   'max_supply': 86712634466,
#   'circulating_supply': 64315576989,
#   'total_supply': 86712634466,
#   'platform': None,
#   'cmc_rank': 27,
#   'last_updated': '2021-12-01T20:27:07.000Z',
#   'quote': {'USD': {'price': 0.11985820630642272,
#     'volume_24h': 416393352.5867306,
#     'volume_change_24h': -22.5362,
#     'percent_change_1h': -2.25501868,
#     'percent_change_24h': 0.23101523,
#     'percent_change_7d': -1.63400064,
#     'percent_change_30d': -11.93771985,
#     'percent_change_60d': 5.67152804,
#     'percent_change_90d': -17.35260372,
#     'market_cap': 7708749695.464175,
#     'market_cap_dominance': 0.2927,
#     'fully_diluted_market_cap': 10393220831.2,
#     'last_updated': '2021-12-01T20:27:07.000Z'}}},
#  {'id': 7129,
#   'name': 'TerraUSD',
#   'symbol': 'UST',
#   'slug': 'terrausd',
#   'num_market_pairs': 115,
#   'date_added': '2020-09-21T00:00:00.000Z',
#   'tags': ['stablecoin', 'binance-smart-chain', 'terra-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 7638549385.976895,
#   'total_supply': 7638549385.976895,
#   'platform': None,
#   'cmc_rank': 28,
#   'last_updated': '2021-12-01T20:28:06.000Z',
#   'quote': {'USD': {'price': 1.0027327819524,
#     'volume_24h': 157828813.71970746,
#     'volume_change_24h': -13.3049,
#     'percent_change_1h': -0.00553831,
#     'percent_change_24h': -0.2312802,
#     'percent_change_7d': 0.01685393,
#     'percent_change_30d': -0.01924022,
#     'percent_change_60d': 0.16726079,
#     'percent_change_90d': 0.24924179,
#     'market_cap': 7659423875.881409,
#     'market_cap_dominance': 0.2908,
#     'fully_diluted_market_cap': 7659423875.88,
#     'last_updated': '2021-12-01T20:28:06.000Z'}}},
#  {'id': 8916,
#   'name': 'Internet Computer',
#   'symbol': 'ICP',
#   'slug': 'internet-computer',
#   'num_market_pairs': 84,
#   'date_added': '2021-03-23T00:00:00.000Z',
#   'tags': ['platform',
#    'distributed-computing',
#    'polychain-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 182805860.1,
#   'total_supply': 475057904.7958072,
#   'platform': None,
#   'cmc_rank': 29,
#   'last_updated': '2021-12-01T20:28:01.000Z',
#   'quote': {'USD': {'price': 40.95774847840791,
#     'volume_24h': 197481451.73152727,
#     'volume_change_24h': -14.6595,
#     'percent_change_1h': -1.29264945,
#     'percent_change_24h': -0.28150518,
#     'percent_change_7d': 0.27508346,
#     'percent_change_30d': -10.6390611,
#     'percent_change_60d': -20.37048039,
#     'percent_change_90d': -38.20898233,
#     'market_cap': 7487316438.354823,
#     'market_cap_dominance': 0.2842,
#     'fully_diluted_market_cap': 19457302177.31,
#     'last_updated': '2021-12-01T20:28:01.000Z'}}},
#  {'id': 2280,
#   'name': 'Filecoin',
#   'symbol': 'FIL',
#   'slug': 'filecoin',
#   'num_market_pairs': 151,
#   'date_added': '2017-12-13T00:00:00.000Z',
#   'tags': ['mineable',
#    'distributed-computing',
#    'filesharing',
#    'storage',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'blockchain-capital-portfolio',
#    'boostvc-portfolio',
#    'dcg-portfolio',
#    'hashkey-capital-portfolio',
#    'a16z-portfolio',
#    'winklevoss-capital-portfolio',
#    'pantera-capital-portfolio',
#    'web3'],
#   'max_supply': None,
#   'circulating_supply': 130063682,
#   'total_supply': 130063682,
#   'platform': None,
#   'cmc_rank': 30,
#   'last_updated': '2021-12-01T20:27:07.000Z',
#   'quote': {'USD': {'price': 54.34219570921945,
#     'volume_24h': 489391747.0712949,
#     'volume_change_24h': -19.1971,
#     'percent_change_1h': -0.45827981,
#     'percent_change_24h': 0.89181455,
#     'percent_change_7d': 9.52396983,
#     'percent_change_30d': -13.54650639,
#     'percent_change_60d': -25.1158222,
#     'percent_change_90d': -29.78366086,
#     'market_cap': 7067946061.9056835,
#     'market_cap_dominance': 0.2682,
#     'fully_diluted_market_cap': 7067946061.91,
#     'last_updated': '2021-12-01T20:27:07.000Z'}}},
#  {'id': 1958,
#   'name': 'TRON',
#   'symbol': 'TRX',
#   'slug': 'tron',
#   'num_market_pairs': 481,
#   'date_added': '2017-09-13T00:00:00.000Z',
#   'tags': ['media', 'payments', 'tron-ecosystem', 'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 71659657369.49,
#   'total_supply': 100850743811.662,
#   'platform': None,
#   'cmc_rank': 31,
#   'last_updated': '2021-12-01T20:28:05.000Z',
#   'quote': {'USD': {'price': 0.09746761103157008,
#     'volume_24h': 1846111735.416463,
#     'volume_change_24h': -24.0942,
#     'percent_change_1h': -1.32007286,
#     'percent_change_24h': 0.1841621,
#     'percent_change_7d': 0.30277336,
#     'percent_change_30d': -2.84793574,
#     'percent_change_60d': 2.70302165,
#     'percent_change_90d': -3.14796138,
#     'market_cap': 6984495611.145036,
#     'market_cap_dominance': 0.2652,
#     'fully_diluted_market_cap': 9788541735.17,
#     'last_updated': '2021-12-01T20:28:05.000Z'}}},
#  {'id': 4195,
#   'name': 'FTX Token',
#   'symbol': 'FTT',
#   'slug': 'ftx-token',
#   'num_market_pairs': 91,
#   'date_added': '2019-07-31T00:00:00.000Z',
#   'tags': ['marketplace',
#    'centralized-exchange',
#    'derivatives',
#    'cms-holdings-portfolio',
#    'kinetic-capital-portfolio',
#    'alameda-research-portfolio',
#    'pantera-capital-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': 352170015,
#   'circulating_supply': 139460202.41874373,
#   'total_supply': 335329538.4859715,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'FTT-F11'},
#   'cmc_rank': 32,
#   'last_updated': '2021-12-01T20:27:16.000Z',
#   'quote': {'USD': {'price': 49.76099515961618,
#     'volume_24h': 168957687.33672038,
#     'volume_change_24h': -8.3866,
#     'percent_change_1h': -1.20740192,
#     'percent_change_24h': -2.04531714,
#     'percent_change_7d': -0.73319717,
#     'percent_change_30d': -15.259138,
#     'percent_change_60d': -12.5905158,
#     'percent_change_90d': -20.59105759,
#     'market_cap': 6939678457.518199,
#     'market_cap_dominance': 0.2634,
#     'fully_diluted_market_cap': 17524330411.78,
#     'last_updated': '2021-12-01T20:27:16.000Z'}}},
#  {'id': 2416,
#   'name': 'THETA',
#   'symbol': 'THETA',
#   'slug': 'theta',
#   'num_market_pairs': 85,
#   'date_added': '2018-01-17T00:00:00.000Z',
#   'tags': ['media',
#    'collectibles-nfts',
#    'content-creation',
#    'video',
#    'metaverse',
#    'huobi-capital-portfolio',
#    'web3'],
#   'max_supply': 1000000000,
#   'circulating_supply': 1000000000,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 33,
#   'last_updated': '2021-12-01T20:27:43.000Z',
#   'quote': {'USD': {'price': 6.516813436661249,
#     'volume_24h': 195219072.43665648,
#     'volume_change_24h': -21.3153,
#     'percent_change_1h': -1.53984903,
#     'percent_change_24h': -2.38952294,
#     'percent_change_7d': -0.75640324,
#     'percent_change_30d': -10.77510502,
#     'percent_change_60d': 5.69713175,
#     'percent_change_90d': -6.55471731,
#     'market_cap': 6516813436.661249,
#     'market_cap_dominance': 0.2473,
#     'fully_diluted_market_cap': 6516813436.66,
#     'last_updated': '2021-12-01T20:27:43.000Z'}}},
#  {'id': 4943,
#   'name': 'Dai',
#   'symbol': 'DAI',
#   'slug': 'multi-collateral-dai',
#   'num_market_pairs': 433,
#   'date_added': '2019-11-22T00:00:00.000Z',
#   'tags': ['defi',
#    'stablecoin',
#    'ethereum-ecosystem',
#    'binance-smart-chain',
#    'avalanche-ecosystem',
#    'polygon-ecosystem',
#    'fantom-ecosystem'],
#   'max_supply': None,
#   'circulating_supply': 6474951713.635377,
#   'total_supply': 6474952202.474523,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x6b175474e89094c44da98b954eedeac495271d0f'},
#   'cmc_rank': 34,
#   'last_updated': '2021-12-01T20:28:04.000Z',
#   'quote': {'USD': {'price': 0.9999151618833295,
#     'volume_24h': 794488894.402425,
#     'volume_change_24h': -6.6236,
#     'percent_change_1h': -0.09846365,
#     'percent_change_24h': 0.03631263,
#     'percent_change_7d': -0.02878464,
#     'percent_change_30d': -0.18053893,
#     'percent_change_60d': -0.11508875,
#     'percent_change_90d': -0.00931204,
#     'market_cap': 6474402390.92646,
#     'market_cap_dominance': 0.2458,
#     'fully_diluted_market_cap': 6474402879.72,
#     'last_updated': '2021-12-01T20:28:04.000Z'}}},
#  {'id': 4642,
#   'name': 'Hedera',
#   'symbol': 'HBAR',
#   'slug': 'hedera',
#   'num_market_pairs': 68,
#   'date_added': '2019-09-17T00:00:00.000Z',
#   'tags': ['dag',
#    'marketplace',
#    'enterprise-solutions',
#    'payments',
#    'dcg-portfolio'],
#   'max_supply': 50000000000,
#   'circulating_supply': 18092792421.137627,
#   'total_supply': 50000000000,
#   'platform': None,
#   'cmc_rank': 35,
#   'last_updated': '2021-12-01T20:27:40.000Z',
#   'quote': {'USD': {'price': 0.3472023994689918,
#     'volume_24h': 76311783.08868062,
#     'volume_change_24h': -54.1967,
#     'percent_change_1h': -0.86425473,
#     'percent_change_24h': -1.67057234,
#     'percent_change_7d': -0.91927626,
#     'percent_change_30d': -13.49412104,
#     'percent_change_60d': -12.79353735,
#     'percent_change_90d': 29.56075051,
#     'market_cap': 6281860941.713373,
#     'market_cap_dominance': 0.2384,
#     'fully_diluted_market_cap': 17360119973.45,
#     'last_updated': '2021-12-01T20:27:40.000Z'}}},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'slug': 'ethereum-classic',
#   'num_market_pairs': 254,
#   'date_added': '2016-07-24T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'ethash',
#    'platform',
#    'smart-contracts',
#    'binance-smart-chain',
#    'dcg-portfolio'],
#   'max_supply': 210700000,
#   'circulating_supply': 131350549.5713796,
#   'total_supply': 210700000,
#   'platform': None,
#   'cmc_rank': 36,
#   'last_updated': '2021-12-01T20:27:35.000Z',
#   'quote': {'USD': {'price': 47.563518732753266,
#     'volume_24h': 672951658.9283423,
#     'volume_change_24h': -6.495,
#     'percent_change_1h': -1.50170792,
#     'percent_change_24h': -1.96359023,
#     'percent_change_7d': -1.06457629,
#     'percent_change_30d': -11.3799825,
#     'percent_change_60d': -12.38515013,
#     'percent_change_90d': -29.66355795,
#     'market_cap': 6247494325.09575,
#     'market_cap_dominance': 0.2372,
#     'fully_diluted_market_cap': 10021633396.99,
#     'last_updated': '2021-12-01T20:27:35.000Z'}}},
#  {'id': 3794,
#   'name': 'Cosmos',
#   'symbol': 'ATOM',
#   'slug': 'cosmos',
#   'num_market_pairs': 187,
#   'date_added': '2019-03-14T00:00:00.000Z',
#   'tags': ['platform',
#    'cosmos-ecosystem',
#    'content-creation',
#    'interoperability',
#    'binance-chain',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'dragonfly-capital-portfolio',
#    'hashkey-capital-portfolio',
#    '1confirmation-portfolio',
#    'paradigm-portfolio',
#    'exnetwork-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 225493808.472749,
#   'total_supply': 283278411.472749,
#   'platform': None,
#   'cmc_rank': 37,
#   'last_updated': '2021-12-01T20:28:01.000Z',
#   'quote': {'USD': {'price': 26.878166148292998,
#     'volume_24h': 375144227.11973804,
#     'volume_change_24h': -19.5377,
#     'percent_change_1h': -1.2987588,
#     'percent_change_24h': -3.94616206,
#     'percent_change_7d': -10.01358558,
#     'percent_change_30d': -28.27716511,
#     'percent_change_60d': -32.80753982,
#     'percent_change_90d': 11.76864092,
#     'market_cap': 6060860049.541906,
#     'market_cap_dominance': 0.23,
#     'fully_diluted_market_cap': 7614004209.79,
#     'last_updated': '2021-12-01T20:28:01.000Z'}}},
#  {'id': 4023,
#   'name': 'Bitcoin BEP2',
#   'symbol': 'BTCB',
#   'slug': 'bitcoin-bep2',
#   'num_market_pairs': 46,
#   'date_added': '2019-06-18T00:00:00.000Z',
#   'tags': ['binance-chain', 'binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 105110.17928512,
#   'total_supply': 112501,
#   'platform': {'id': 1839,
#    'name': 'Binance Chain (BEP2)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': 'BTCB-1DE'},
#   'cmc_rank': 38,
#   'last_updated': '2021-12-01T20:28:05.000Z',
#   'quote': {'USD': {'price': 57019.841628881186,
#     'volume_24h': 83336710.85769874,
#     'volume_change_24h': 101.634,
#     'percent_change_1h': -0.53245405,
#     'percent_change_24h': -0.88543279,
#     'percent_change_7d': 0.28914785,
#     'percent_change_30d': -6.72961059,
#     'percent_change_60d': 18.94528367,
#     'percent_change_90d': 15.22829756,
#     'market_cap': 5993365776.420851,
#     'market_cap_dominance': 0.2276,
#     'fully_diluted_market_cap': 6414789203.09,
#     'last_updated': '2021-12-01T20:28:05.000Z'}}},
#  {'id': 6210,
#   'name': 'The Sandbox',
#   'symbol': 'SAND',
#   'slug': 'the-sandbox',
#   'num_market_pairs': 135,
#   'date_added': '2020-08-05T00:00:00.000Z',
#   'tags': ['collectibles-nfts',
#    'content-creation',
#    'gaming',
#    'ethereum-ecosystem',
#    'binance-launchpad',
#    'metaverse',
#    'play-to-earn',
#    'animoca-brands-portfolio'],
#   'max_supply': 3000000000,
#   'circulating_supply': 913246119.2233225,
#   'total_supply': 3000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   'cmc_rank': 39,
#   'last_updated': '2021-12-01T20:27:20.000Z',
#   'quote': {'USD': {'price': 6.438709887447623,
#     'volume_24h': 2025371319.768649,
#     'volume_change_24h': -31.75,
#     'percent_change_1h': -3.11745052,
#     'percent_change_24h': -4.1438414,
#     'percent_change_7d': -11.63920667,
#     'percent_change_30d': 208.94362097,
#     'percent_change_60d': 704.41753217,
#     'percent_change_90d': 557.07986999,
#     'market_cap': 5880126817.516377,
#     'market_cap_dominance': 0.224,
#     'fully_diluted_market_cap': 19316129662.34,
#     'last_updated': '2021-12-01T20:27:20.000Z'}}},
#  {'id': 3513,
#   'name': 'Fantom',
#   'symbol': 'FTM',
#   'slug': 'fantom',
#   'num_market_pairs': 121,
#   'date_added': '2018-10-29T00:00:00.000Z',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'defi',
#    'research',
#    'scaling',
#    'smart-contracts',
#    'binance-smart-chain',
#    'fantom-ecosystem'],
#   'max_supply': 3175000000,
#   'circulating_supply': 2545006273,
#   'total_supply': 2545006273,
#   'platform': None,
#   'cmc_rank': 40,
#   'last_updated': '2021-12-01T20:27:52.000Z',
#   'quote': {'USD': {'price': 2.2091565584038046,
#     'volume_24h': 405556748.8615108,
#     'volume_change_24h': -22.2968,
#     'percent_change_1h': -0.09228621,
#     'percent_change_24h': 2.64258241,
#     'percent_change_7d': -11.25992516,
#     'percent_change_30d': -18.24188194,
#     'percent_change_60d': 49.07300036,
#     'percent_change_90d': 153.16531963,
#     'market_cap': 5622317299.176774,
#     'market_cap_dominance': 0.2134,
#     'fully_diluted_market_cap': 7014072072.93,
#     'last_updated': '2021-12-01T20:27:52.000Z'}}},
#  {'id': 6535,
#   'name': 'NEAR Protocol',
#   'symbol': 'NEAR',
#   'slug': 'near-protocol',
#   'num_market_pairs': 69,
#   'date_added': '2020-08-11T00:00:00.000Z',
#   'tags': ['platform',
#    'staking',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'arrington-xrp-capital-portfolio',
#    'coinfund-portfolio',
#    'electric-capital-portfolio',
#    'fabric-ventures-portfolio',
#    'kinetic-capital-portfolio',
#    'near-protocol-ecosystem',
#    'k300-ventures-portfolio'],
#   'max_supply': 1000000000,
#   'circulating_supply': 567618812,
#   'total_supply': 1000000000,
#   'platform': None,
#   'cmc_rank': 41,
#   'last_updated': '2021-12-01T20:27:50.000Z',
#   'quote': {'USD': {'price': 8.443455559258696,
#     'volume_24h': 132668280.69760336,
#     'volume_change_24h': -28.4173,
#     'percent_change_1h': -1.40666668,
#     'percent_change_24h': -4.21046646,
#     'percent_change_7d': -8.51266429,
#     'percent_change_30d': -15.53784995,
#     'percent_change_60d': 6.43504122,
#     'percent_change_90d': 55.09691106,
#     'market_cap': 4792664213.721217,
#     'market_cap_dominance': 0.1826,
#     'fully_diluted_market_cap': 8443455559.26,
#     'last_updated': '2021-12-01T20:27:50.000Z'}}},
#  {'id': 2011,
#   'name': 'Tezos',
#   'symbol': 'XTZ',
#   'slug': 'tezos',
#   'num_market_pairs': 174,
#   'date_added': '2017-10-06T00:00:00.000Z',
#   'tags': ['pos',
#    'platform',
#    'enterprise-solutions',
#    'collectibles-nfts',
#    'defi',
#    'smart-contracts',
#    'binance-smart-chain',
#    'polychain-capital-portfolio',
#    'boostvc-portfolio',
#    'winklevoss-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 868937218.145953,
#   'total_supply': 897665550.533996,
#   'platform': None,
#   'cmc_rank': 42,
#   'last_updated': '2021-12-01T20:28:03.000Z',
#   'quote': {'USD': {'price': 5.220540568749552,
#     'volume_24h': 270178083.95765007,
#     'volume_change_24h': -67.8525,
#     'percent_change_1h': -1.42363223,
#     'percent_change_24h': -8.75358991,
#     'percent_change_7d': 6.71397488,
#     'percent_change_30d': -16.43261152,
#     'percent_change_60d': -30.73119509,
#     'percent_change_90d': -1.73694202,
#     'market_cap': 4536321999.027328,
#     'market_cap_dominance': 0.1722,
#     'fully_diluted_market_cap': 4686299423.73,
#     'last_updated': '2021-12-01T20:28:03.000Z'}}},
#  {'id': 6719,
#   'name': 'The Graph',
#   'symbol': 'GRT',
#   'slug': 'the-graph',
#   'num_market_pairs': 141,
#   'date_added': '2020-12-17T00:00:00.000Z',
#   'tags': ['ai-big-data',
#    'enterprise-solutions',
#    'defi',
#    'binance-smart-chain',
#    'coinbase-ventures-portfolio',
#    'solana-ecosystem',
#    'analytics',
#    'coinfund-portfolio',
#    'dcg-portfolio',
#    'fabric-ventures-portfolio',
#    'framework-ventures-portfolio',
#    'ledgerprime-portfolio',
#    'multicoin-capital-portfolio',
#    'parafi-capital',
#    'polygon-ecosystem',
#    'fantom-ecosystem',
#    'web3',
#    'near-protocol-ecosystem'],
#   'max_supply': 10057044431,
#   'circulating_supply': 4715735200,
#   'total_supply': 10000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
# ...
#     'percent_change_24h': -3.17608735,
#     'percent_change_7d': -2.331292,
#     'percent_change_30d': 122.04507629,
#     'percent_change_60d': 109.98865884,
#     'percent_change_90d': 79.09120752,
#     'market_cap': 101269147.26284648,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 189389868.51,
#     'last_updated': '2021-12-01T20:27:51.000Z'}}},
#  {'id': 8258,
#   'name': 'CUDOS',
#   'symbol': 'CUDOS',
#   'slug': 'cudos',
#   'num_market_pairs': 10,
#   'date_added': '2021-01-13T00:00:00.000Z',
#   'tags': ['algorand-ecosystem', 'exnetwork-capital-portfolio'],
#   'max_supply': 10000000000,
#   'circulating_supply': 2176487633.037567,
#   'total_supply': 10000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x817bbDbC3e8A1204f3691d14bB44992841e3dB35'},
#   'cmc_rank': 486,
#   'last_updated': '2021-12-01T20:27:07.000Z',
#   'quote': {'USD': {'price': 0.04640599638254395,
#     'volume_24h': 1967077.76884838,
#     'volume_change_24h': 91.9586,
#     'percent_change_1h': -0.22966977,
#     'percent_change_24h': -0.50152387,
#     'percent_change_7d': 6.19371226,
#     'percent_change_30d': 33.93079683,
#     'percent_change_60d': 50.36932131,
#     'percent_change_90d': 42.91100101,
#     'market_cap': 101002077.225393,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 464059963.83,
#     'last_updated': '2021-12-01T20:27:07.000Z'}}},
#  {'id': 7958,
#   'name': 'Venus USDC',
#   'symbol': 'vUSDC',
#   'slug': 'venus-usdc',
#   'num_market_pairs': 1,
#   'date_added': '2020-12-12T00:00:00.000Z',
#   'tags': ['binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 4771015133,
#   'total_supply': 4771015133,
#   'platform': {'id': 1839,
#    'name': 'Binance Smart Chain (BEP20)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': '0xeca88125a5adbe82614ffc12d0db554e2e2867c8'},
#   'cmc_rank': 487,
#   'last_updated': '2021-12-01T20:28:02.000Z',
#   'quote': {'USD': {'price': 0.021135965781924292,
#     'volume_24h': 0,
#     'volume_change_24h': 0,
#     'percent_change_1h': -0.16701111,
#     'percent_change_24h': 0.02633056,
#     'percent_change_7d': 0.06667153,
#     'percent_change_30d': 0.63507122,
#     'percent_change_60d': 1.36913729,
#     'percent_change_90d': 1.7491285,
#     'market_cap': 100840012.59613098,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 100840012.6,
#     'last_updated': '2021-12-01T20:28:02.000Z'}}},
#  {'id': 2866,
#   'name': 'Sentinel Protocol',
#   'symbol': 'UPP',
#   'slug': 'sentinel-protocol',
#   'num_market_pairs': 3,
#   'date_added': '2018-06-18T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 459429451.2862929,
#   'total_supply': 500000000.00000006,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xc86d054809623432210c107af2e3f619dcfbf652'},
#   'cmc_rank': 489,
#   'last_updated': '2021-12-01T20:28:06.000Z',
#   'quote': {'USD': {'price': 0.21924283187382823,
#     'volume_24h': 9200664.78639347,
#     'volume_change_24h': -5.4106,
#     'percent_change_1h': -0.10754496,
#     'percent_change_24h': 1.80724367,
#     'percent_change_7d': 5.98221979,
#     'percent_change_30d': -2.92803457,
#     'percent_change_60d': 8.74467344,
#     'percent_change_90d': 8.02698341,
#     'market_cap': 100726613.94624588,
#     'market_cap_dominance': 0.0038,
#     'fully_diluted_market_cap': 109621415.94,
#     'last_updated': '2021-12-01T20:28:06.000Z'}}},
#  {'id': 2989,
#   'name': 'STASIS EURO',
#   'symbol': 'EURS',
#   'slug': 'stasis-euro',
#   'num_market_pairs': 12,
#   'date_added': '2018-07-30T00:00:00.000Z',
#   'tags': ['marketplace', 'stablecoin', 'asset-backed-stablecoin', 'wallet'],
#   'max_supply': None,
#   'circulating_supply': 89225940,
#   'total_supply': 89225940,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xdb25f211ab05b1c97d595516f45794528a807ad8'},
#   'cmc_rank': 488,
#   'last_updated': '2021-12-01T20:28:05.000Z',
#   'quote': {'USD': {'price': 1.1282266766862563,
#     'volume_24h': 6892330.47430934,
#     'volume_change_24h': -13.0599,
#     'percent_change_1h': -0.97225955,
#     'percent_change_24h': -0.66220899,
#     'percent_change_7d': 0.78885862,
#     'percent_change_30d': -2.45446185,
#     'percent_change_60d': -2.483185,
#     'percent_change_90d': -4.63185515,
#     'market_cap': 100667085.7604073,
#     'market_cap_dominance': 0.0038,
#     'fully_diluted_market_cap': 100667085.76,
#     'last_updated': '2021-12-01T20:28:05.000Z'}}},
#  {'id': 8707,
#   'name': 'Alpaca Finance',
#   'symbol': 'ALPACA',
#   'slug': 'alpaca-finance',
#   'num_market_pairs': 34,
#   'date_added': '2021-03-06T00:00:00.000Z',
#   'tags': ['defi',
#    'binance-smart-chain',
#    'lending-borowing',
#    'polygon-ecosystem'],
#   'max_supply': 188000000,
#   'circulating_supply': 141603872.2278711,
#   'total_supply': 144858125.18686786,
#   'platform': {'id': 1839,
#    'name': 'Binance Smart Chain (BEP20)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': '0x8f0528ce5ef7b51152a59745befdd91d97091d2f'},
#   'cmc_rank': 490,
#   'last_updated': '2021-12-01T20:27:55.000Z',
#   'quote': {'USD': {'price': 0.7045546078562445,
#     'volume_24h': 17795006.30474436,
#     'volume_change_24h': 18.3233,
#     'percent_change_1h': -0.61764599,
#     'percent_change_24h': 2.09342749,
#     'percent_change_7d': -2.77127151,
#     'percent_change_30d': -23.7117913,
#     'percent_change_60d': -22.18313114,
#     'percent_change_90d': -42.10839672,
#     'market_cap': 99767660.66843346,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 132456266.28,
#     'last_updated': '2021-12-01T20:27:55.000Z'}}},
#  {'id': 3795,
#   'name': 'ZEON',
#   'symbol': 'ZEON',
#   'slug': 'zeon',
#   'num_market_pairs': 3,
#   'date_added': '2019-03-15T00:00:00.000Z',
#   'tags': [],
#   'max_supply': None,
#   'circulating_supply': 30529103436.312363,
#   'total_supply': 50000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xe5b826ca2ca02f09c1725e9bd98d9a8874c30532'},
#   'cmc_rank': 491,
#   'last_updated': '2021-12-01T20:28:02.000Z',
#   'quote': {'USD': {'price': 0.0032524067407279527,
#     'volume_24h': 227299.11901758,
#     'volume_change_24h': 3548.3854,
#     'percent_change_1h': -1.41356314,
#     'percent_change_24h': 282.04471517,
#     'percent_change_7d': 62.39325692,
#     'percent_change_30d': 71.5229866,
#     'percent_change_60d': 56.37608772,
#     'percent_change_90d': 3.68274491,
#     'market_cap': 99293061.80464323,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 162620337.04,
#     'last_updated': '2021-12-01T20:28:02.000Z'}}},
#  {'id': 1856,
#   'name': 'district0x',
#   'symbol': 'DNT',
#   'slug': 'district0x',
#   'num_market_pairs': 29,
#   'date_added': '2017-08-03T00:00:00.000Z',
#   'tags': ['platform', 'payments', 'reputation', 'boostvc-portfolio', 'web3'],
#   'max_supply': None,
#   'circulating_supply': 600000000,
#   'total_supply': 1000000000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0abdace70d3790235af448c88547603b945604ea'},
#   'cmc_rank': 492,
#   'last_updated': '2021-12-01T20:28:03.000Z',
#   'quote': {'USD': {'price': 0.16481459032442594,
#     'volume_24h': 7873921.8341002,
#     'volume_change_24h': -15.2758,
#     'percent_change_1h': -1.8446067,
#     'percent_change_24h': -0.50190735,
#     'percent_change_7d': 5.71285488,
#     'percent_change_30d': -0.89417378,
#     'percent_change_60d': 3.23054488,
#     'percent_change_90d': -13.11192856,
#     'market_cap': 98888754.19465557,
#     'market_cap_dominance': 0.0038,
#     'fully_diluted_market_cap': 164814590.32,
#     'last_updated': '2021-12-01T20:28:03.000Z'}}},
#  {'id': 7824,
#   'name': 'Vai',
#   'symbol': 'VAI',
#   'slug': 'vai',
#   'num_market_pairs': 29,
#   'date_added': '2020-12-01T00:00:00.000Z',
#   'tags': ['defi',
#    'stablecoin',
#    'asset-backed-stablecoin',
#    'binance-smart-chain'],
#   'max_supply': 0,
#   'circulating_supply': 110487204,
#   'total_supply': 110487204,
#   'platform': {'id': 1839,
#    'name': 'Binance Smart Chain (BEP20)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': '0x4bd17003473389a42daf6a0a729f6fdb328bbbd7'},
#   'cmc_rank': 493,
#   'last_updated': '2021-12-01T20:27:59.000Z',
#   'quote': {'USD': {'price': 0.8980446361332926,
#     'volume_24h': 452081.3183368,
#     'volume_change_24h': 55.2991,
#     'percent_change_1h': 0.0487221,
#     'percent_change_24h': -1.55396758,
#     'percent_change_7d': -1.39211798,
#     'percent_change_30d': 3.12754186,
#     'percent_change_60d': -10.40821568,
#     'percent_change_90d': 17.70463026,
#     'market_cap': 99222440.91356486,
#     'market_cap_dominance': 0.0038,
#     'fully_diluted_market_cap': 0,
#     'last_updated': '2021-12-01T20:27:59.000Z'}}},
#  {'id': 7678,
#   'name': 'KeeperDAO',
#   'symbol': 'ROOK',
#   'slug': 'keeperdao',
#   'num_market_pairs': 19,
#   'date_added': '2020-11-15T00:00:00.000Z',
#   'tags': ['defi',
#    'yield-farming',
#    'three-arrows-capital-portfolio',
#    'alameda-research-portfolio'],
#   'max_supply': 1500000,
#   'circulating_supply': 617636.34822193,
#   'total_supply': 1226310,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xfa5047c9c78b8877af97bdcb85db743fd7313d4a'},
#   'cmc_rank': 494,
#   'last_updated': '2021-12-01T20:27:55.000Z',
#   'quote': {'USD': {'price': 160.24004313639645,
#     'volume_24h': 1663293.06463013,
#     'volume_change_24h': 20.0508,
#     'percent_change_1h': -0.43349895,
#     'percent_change_24h': -2.97917638,
#     'percent_change_7d': -1.11973454,
#     'percent_change_30d': -46.21897185,
#     'percent_change_60d': 6.0694846,
#     'percent_change_90d': -20.32910251,
#     'market_cap': 98970075.08168843,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 240360064.7,
#     'last_updated': '2021-12-01T20:27:55.000Z'}}},
#  {'id': 1768,
#   'name': 'Ambire AdEx',
#   'symbol': 'ADX',
#   'slug': 'adx-net',
#   'num_market_pairs': 21,
#   'date_added': '2017-07-01T00:00:00.000Z',
#   'tags': ['marketing',
#    'smart-contracts',
#    'substrate',
#    'polkadot',
#    'binance-smart-chain',
#    'polkadot-ecosystem'],
#   'max_supply': 150000000,
#   'circulating_supply': 136140181.88552818,
#   'total_supply': 144582658.22552815,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xade00c28244d5ce17d72e40330b1c318cd12b7c3'},
#   'cmc_rank': 496,
#   'last_updated': '2021-12-01T20:27:40.000Z',
#   'quote': {'USD': {'price': 0.7225555093969118,
#     'volume_24h': 8786138.20303503,
#     'volume_change_24h': 57.3539,
#     'percent_change_1h': -1.21135042,
#     'percent_change_24h': -0.06420553,
#     'percent_change_7d': 0.69478598,
#     'percent_change_30d': -17.50323395,
#     'percent_change_60d': 56.74375985,
#     'percent_change_90d': 29.2336214,
#     'market_cap': 98368838.47168604,
#     'market_cap_dominance': 0.0037,
#     'fully_diluted_market_cap': 108383326.41,
#     'last_updated': '2021-12-01T20:27:40.000Z'}}},
#  {'id': 5601,
#   'name': 'xDai',
#   'symbol': 'STAKE',
#   'slug': 'xdai',
#   'num_market_pairs': 25,
#   'date_added': '2020-05-19T00:00:00.000Z',
#   'tags': ['defi', 'exnetwork-capital-portfolio'],
#   'max_supply': 8537500,
#   'circulating_supply': 7430506.44538684,
#   'total_supply': 8414577.83438751,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6'},
#   'cmc_rank': 495,
#   'last_updated': '2021-12-01T20:27:33.000Z',
#   'quote': {'USD': {'price': 13.239787987562273,
#     'volume_24h': 5215200.90747963,
#     'volume_change_24h': 61.09,
#     'percent_change_1h': 0.69202324,
#     'percent_change_24h': -5.30868888,
#     'percent_change_7d': 14.35961828,
#     'percent_change_30d': 0.14689147,
#     'percent_change_60d': 2.75240533,
#     'percent_change_90d': 45.59778761,
#     'market_cap': 98378329.97713673,
#     'market_cap_dominance': 0.0037,
#     'fully_diluted_market_cap': 113034689.94,
#     'last_updated': '2021-12-01T20:27:33.000Z'}}},
#  {'id': 7960,
#   'name': 'Venus XVS',
#   'symbol': 'vXVS',
#   'slug': 'venus-xvs',
#   'num_market_pairs': 1,
#   'date_added': '2020-12-12T00:00:00.000Z',
#   'tags': ['binance-smart-chain'],
#   'max_supply': None,
#   'circulating_supply': 224433925,
#   'total_supply': 224433925,
#   'platform': {'id': 1839,
#    'name': 'Binance Smart Chain (BEP20)',
#    'symbol': 'BNB',
#    'slug': 'binance-coin',
#    'token_address': '0x151B1e2635A717bcDc836ECd6FbB62B674FE3E1D'},
#   'cmc_rank': 497,
#   'last_updated': '2021-12-01T20:28:02.000Z',
#   'quote': {'USD': {'price': 0.4362938548068975,
#     'volume_24h': 0,
#     'volume_change_24h': 0,
#     'percent_change_1h': -1.60905952,
#     'percent_change_24h': -2.2859379,
#     'percent_change_7d': -9.31869691,
#     'percent_change_30d': -15.38111605,
#     'percent_change_60d': -19.00765714,
#     'percent_change_90d': -32.71701799,
#     'market_cap': 97919142.28769211,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 97919142.29,
#     'last_updated': '2021-12-01T20:28:02.000Z'}}},
#  {'id': 1414,
#   'name': 'Firo',
#   'symbol': 'FIRO',
#   'slug': 'firo',
#   'num_market_pairs': 37,
#   'date_added': '2016-10-06T00:00:00.000Z',
#   'tags': ['mineable',
#    'pow',
#    'medium-of-exchange',
#    'privacy',
#    'zero-knowledge-proofs',
#    'masternodes'],
#   'max_supply': 21400000,
#   'circulating_supply': 12631111.80617914,
#   'total_supply': 12427854.74033085,
#   'platform': None,
#   'cmc_rank': 499,
#   'last_updated': '2021-12-01T20:27:50.000Z',
#   'quote': {'USD': {'price': 7.67145671217702,
#     'volume_24h': 3459266.11387759,
#     'volume_change_24h': -3.994,
#     'percent_change_1h': -1.13491206,
#     'percent_change_24h': -0.93749644,
#     'percent_change_7d': -6.34797302,
#     'percent_change_30d': -10.03055133,
#     'percent_change_60d': 7.51326435,
#     'percent_change_90d': -7.45373992,
#     'market_cap': 96899027.44777136,
#     'market_cap_dominance': 0.0037,
#     'fully_diluted_market_cap': 164169173.64,
#     'last_updated': '2021-12-01T20:27:50.000Z'}}},
#  {'id': 2553,
#   'name': 'Refereum',
#   'symbol': 'RFR',
#   'slug': 'refereum',
#   'num_market_pairs': 7,
#   'date_added': '2018-03-01T00:00:00.000Z',
#   'tags': ['media', 'content-creation', 'gaming', 'kinetic-capital-portfolio'],
#   'max_supply': None,
#   'circulating_supply': 4999180100,
#   'total_supply': 4999650000,
#   'platform': {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'slug': 'ethereum',
#    'token_address': '0xd0929d411954c47438dc1d871dd6081f5c5e149c'},
#   'cmc_rank': 498,
#   'last_updated': '2021-12-01T20:27:54.000Z',
#   'quote': {'USD': {'price': 0.019383559832265786,
#     'volume_24h': 8885271.19041042,
#     'volume_change_24h': -50.2157,
#     'percent_change_1h': -0.09747395,
#     'percent_change_24h': -3.23022552,
#     'percent_change_7d': 0.16823832,
#     'percent_change_30d': 12.44404134,
#     'percent_change_60d': 50.54351581,
#     'percent_change_90d': 30.47256364,
#     'market_cap': 96901906.58062245,
#     'market_cap_dominance': 0.0037,
#     'fully_diluted_market_cap': 96911014.92,
#     'last_updated': '2021-12-01T20:27:54.000Z'}}},
#  {'id': 7576,
#   'name': 'Kava Lend',
#   'symbol': 'HARD',
#   'slug': 'hard-protocol',
#   'num_market_pairs': 19,
#   'date_added': '2020-11-02T00:00:00.000Z',
#   'tags': ['cosmos-ecosystem',
#    'defi',
#    'binance-launchpool',
#    'lending-borowing'],
#   'max_supply': 200000000,
#   'circulating_supply': 94166667,
#   'total_supply': 200000000,
#   'platform': None,
#   'cmc_rank': 500,
#   'last_updated': '2021-12-01T20:27:19.000Z',
#   'quote': {'USD': {'price': 1.0253486051309502,
#     'volume_24h': 13592529.88167712,
#     'volume_change_24h': 4.5742,
#     'percent_change_1h': -1.07329604,
#     'percent_change_24h': -3.81559959,
#     'percent_change_7d': -0.24620574,
#     'percent_change_30d': -0.943476,
#     'percent_change_60d': 1.20454675,
#     'percent_change_90d': -13.63822251,
#     'market_cap': 96553660.65828067,
#     'market_cap_dominance': 0,
#     'fully_diluted_market_cap': 205069721.03,
#     'last_updated': '2021-12-01T20:27:19.000Z'}}}]
